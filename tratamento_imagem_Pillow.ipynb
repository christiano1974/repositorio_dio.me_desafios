# %% [markdown]
# <a href="https://colab.research.google.com/github/christiano1974/repositorio_dio.me_desafios/blob/main/tratamento_imagem_Pillow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Pillow

# %%
from PIL import Image

# %%
imagem = Image.open('/content/machine-redimensionado.jpg')

# %%
print(imagem.mode)
print(imagem.format)
print(imagem.size)
# Out:
# RGB
# JPEG
# (1200, 600)

# %%
imagem
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x600>

# %%
imagem_1 = imagem.convert(mode = 'L')
imagem_1
# Out:
# <PIL.Image.Image image mode=L size=1200x600>
